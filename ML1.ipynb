# %%
# Import necessary libraries
import tensorflow as tf
from keras.models import Sequential # type: ignore
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout # type: ignore
from keras.applications import MobileNetV2 # type: ignore
#from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam # type: ignore

# %%
# Define constants                             
IMG_SIZE = (128, 128)  # Image size for resizing
BATCH_SIZE = 32
EPOCHS = 20
NUM_CLASSES = 5  # Replace with the number of skin disease categories

# Data preprocessing
datagen = ImageDataGenerator(
    rescale=1.0/255,
    validation_split=0.2,  # 20% for validation
    horizontal_flip=True,
    rotation_range=20,
    zoom_range=0.2
)

train_data = datagen.flow_from_directory(
    'path_to_dataset',  # Replace with the path to your dataset
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training'
)

val_data = datagen.flow_from_directory(
    'path_to_dataset',
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation'
)

# 1. Simple CNN Model
def build_simple_cnn():
    model = Sequential([
        Conv2D(32, (3, 3), activation='relu', input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3)),
        MaxPooling2D((2, 2)),
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Flatten(),
        Dense(128, activation='relu'),
        Dropout(0.5),
        Dense(NUM_CLASSES, activation='softmax')
    ])
    model.compile(optimizer=Adam(learning_rate=0.001),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# 2. Transfer Learning with MobileNetV2
def build_transfer_learning_model():
    base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3))
    base_model.trainable = False  # Freeze the base model

    model = Sequential([
        base_model,
        Flatten(),
        Dense(128, activation='relu'),
        Dropout(0.5),
        Dense(NUM_CLASSES, activation='softmax')
    ])
    model.compile(optimizer=Adam(learning_rate=0.001),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# 3. Advanced CNN Model
def build_advanced_cnn():
    model = Sequential([
        Conv2D(32, (3, 3), activation='relu', input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3)),
        MaxPooling2D((2, 2)),
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Flatten(),
        Dense(256, activation='relu'),
        Dropout(0.5),
        Dense(NUM_CLASSES, activation='softmax')
    ])
    model.compile(optimizer=Adam(learning_rate=0.001),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# Train and evaluate models
simple_cnn = build_simple_cnn()
simple_cnn.fit(train_data, validation_data=val_data, epochs=EPOCHS)

transfer_model = build_transfer_learning_model()
transfer_model.fit(train_data, validation_data=val_data, epochs=EPOCHS)

advanced_cnn = build_advanced_cnn()
advanced_cnn.fit(train_data, validation_data=val_data, epochs=EPOCHS)
# Out:
# Requirement already satisfied: tensorflow in c:\users\maxkr\desktop\sr.proj-stopicss2-proj-code-repo\.venv\lib\site-packages (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\maxkr\desktop\sr.proj-stopicss2-proj-code-repo\.venv\lib\site-packages (from tensorflow) (2.2.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\maxkr\desktop\sr.proj-stopicss2-proj-code-repo\.venv\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\maxkr\desktop\sr.proj-stopicss2-proj-code-repo\.venv\lib\site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\maxkr\desktop\sr.proj-stopicss2-proj-code-repo\.venv\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\maxkr\desktop\sr.proj-stopicss2-proj-code-repo\.venv\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\maxkr\desktop\sr.proj-stopicss2-proj-code-repo\.venv\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\maxkr\desktop\sr.proj-stopicss2-proj-code-repo\.venv\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\maxkr\desktop\sr.proj-stopicss2-proj-code-repo\.venv\lib\site-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\maxkr\desktop\sr.proj-stopicss2-proj-code-repo\.venv\lib\site-packages (from tensorflow) (5.29.4)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\maxkr\desktop\sr.proj-stopicss2-proj-code-repo\.venv\lib\site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\maxkr\desktop\sr.proj-stopicss2-proj-code-repo\.venv\lib\site-packages (from tensorflow) (78.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\maxkr\desktop\sr.proj-stopicss2-proj-code-repo\.venv\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\maxkr\desktop\sr.proj-stopicss2-proj-code-repo\.venv\lib\site-packages (from tensorflow) (3.0.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\maxkr\desktop\sr.proj-stopicss2-proj-code-repo\.venv\lib\site-packages (from tensorflow) (4.13.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\maxkr\desktop\sr.proj-stopicss2-proj-code-repo\.venv\lib\site-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\maxkr\desktop\sr.proj-stopicss2-proj-code-repo\.venv\lib\site-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard~=2.19.0 in c:\users\maxkr\desktop\sr.proj-stopicss2-proj-code-repo\.venv\lib\site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\maxkr\desktop\sr.proj-stopicss2-proj-code-repo\.venv\lib\site-packages (from tensorflow) (3.9.1)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in c:\users\maxkr\desktop\sr.proj-stopicss2-proj-code-repo\.venv\lib\site-packages (from tensorflow) (2.1.3)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\maxkr\desktop\sr.proj-stopicss2-proj-code-repo\.venv\lib\site-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in c:\users\maxkr\desktop\sr.proj-stopicss2-proj-code-repo\.venv\lib\site-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\maxkr\desktop\sr.proj-stopicss2-proj-code-repo\.venv\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\users\maxkr\desktop\sr.proj-stopicss2-proj-code-repo\.venv\lib\site-packages (from keras>=3.5.0->tensorflow) (14.0.0)
# Requirement already satisfied: namex in c:\users\maxkr\desktop\sr.proj-stopicss2-proj-code-repo\.venv\lib\site-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\maxkr\desktop\sr.proj-stopicss2-proj-code-repo\.venv\lib\site-packages (from keras>=3.5.0->tensorflow) (0.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\maxkr\desktop\sr.proj-stopicss2-proj-code-repo\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\maxkr\desktop\sr.proj-stopicss2-proj-code-repo\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\maxkr\desktop\sr.proj-stopicss2-proj-code-repo\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\maxkr\desktop\sr.proj-stopicss2-proj-code-repo\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\maxkr\desktop\sr.proj-stopicss2-proj-code-repo\.venv\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\maxkr\desktop\sr.proj-stopicss2-proj-code-repo\.venv\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\maxkr\desktop\sr.proj-stopicss2-proj-code-repo\.venv\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\maxkr\desktop\sr.proj-stopicss2-proj-code-repo\.venv\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\maxkr\desktop\sr.proj-stopicss2-proj-code-repo\.venv\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\maxkr\desktop\sr.proj-stopicss2-proj-code-repo\.venv\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\maxkr\desktop\sr.proj-stopicss2-proj-code-repo\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 6
#       4 # Import necessary libraries
#       5 import tensorflow as tf
# ----> 6 from tensorflow.keras.models import Sequential
#       7 from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
#       8 from tensorflow.keras.applications import MobileNetV2
#
# File c:\Users\maxkr\Desktop\Sr.Proj-STopicsS2-Proj-Code-Repo\.venv\Lib\site-packages\keras\_tf_keras\keras\__init__.py:7
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 7 from keras.api import activations
#       8 from keras.api import applications
#       9 from keras.api import callbacks
#
# File c:\Users\maxkr\Desktop\Sr.Proj-STopicsS2-Proj-Code-Repo\.venv\Lib\site-packages\keras\__init__.py:2
#       1 # DO NOT EDIT. Generated by api_gen.sh
# ----> 2 from keras.api import DTypePolicy
#       3 from keras.api import FloatDTypePolicy
#       4 from keras.api import Function
#
# File c:\Users\maxkr\Desktop\Sr.Proj-STopicsS2-Proj-Code-Repo\.venv\Lib\site-packages\keras\api\__init__.py:8
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 8 from keras.api import activations
#       9 from keras.api import applications
#      10 from keras.api import backend
#
# File c:\Users\maxkr\Desktop\Sr.Proj-STopicsS2-Proj-Code-Repo\.venv\Lib\site-packages\keras\api\activations\__init__.py:7
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 7 from keras.src.activations import deserialize
#       8 from keras.src.activations import get
#       9 from keras.src.activations import serialize
#
# File c:\Users\maxkr\Desktop\Sr.Proj-STopicsS2-Proj-Code-Repo\.venv\Lib\site-packages\keras\src\__init__.py:1
# ----> 1 from keras.src import activations
#       2 from keras.src import applications
#       3 from keras.src import backend
#
# File c:\Users\maxkr\Desktop\Sr.Proj-STopicsS2-Proj-Code-Repo\.venv\Lib\site-packages\keras\src\activations\__init__.py:33
#      31 from keras.src.activations.activations import threshold
#      32 from keras.src.api_export import keras_export
# ---> 33 from keras.src.saving import object_registration
#      34 from keras.src.saving import serialization_lib
#      36 ALL_OBJECTS = {
#      37     relu,
#      38     leaky_relu,
#    (...)     65     sparsemax,
#      66 }
#
# File c:\Users\maxkr\Desktop\Sr.Proj-STopicsS2-Proj-Code-Repo\.venv\Lib\site-packages\keras\src\saving\__init__.py:7
#       5 from keras.src.saving.object_registration import get_registered_object
#       6 from keras.src.saving.object_registration import register_keras_serializable
# ----> 7 from keras.src.saving.saving_api import load_model
#       8 from keras.src.saving.serialization_lib import deserialize_keras_object
#       9 from keras.src.saving.serialization_lib import serialize_keras_object
#
# File c:\Users\maxkr\Desktop\Sr.Proj-STopicsS2-Proj-Code-Repo\.venv\Lib\site-packages\keras\src\saving\saving_api.py:7
#       4 from absl import logging
#       6 from keras.src.api_export import keras_export
# ----> 7 from keras.src.legacy.saving import legacy_h5_format
#       8 from keras.src.saving import saving_lib
#       9 from keras.src.utils import file_utils
#
# File c:\Users\maxkr\Desktop\Sr.Proj-STopicsS2-Proj-Code-Repo\.venv\Lib\site-packages\keras\src\legacy\saving\legacy_h5_format.py:13
#      11 from keras.src.legacy.saving import json_utils
#      12 from keras.src.legacy.saving import saving_options
# ---> 13 from keras.src.legacy.saving import saving_utils
#      14 from keras.src.saving import object_registration
#      15 from keras.src.utils import io_utils
#
# File c:\Users\maxkr\Desktop\Sr.Proj-STopicsS2-Proj-Code-Repo\.venv\Lib\site-packages\keras\src\legacy\saving\saving_utils.py:10
#       8 from keras.src import losses
#       9 from keras.src import metrics as metrics_module
# ---> 10 from keras.src import models
#      11 from keras.src import optimizers
#      12 from keras.src import tree
#
# File c:\Users\maxkr\Desktop\Sr.Proj-STopicsS2-Proj-Code-Repo\.venv\Lib\site-packages\keras\src\models\__init__.py:1
# ----> 1 from keras.src.models.functional import Functional
#       2 from keras.src.models.model import Model
#       3 from keras.src.models.sequential import Sequential
#
# File c:\Users\maxkr\Desktop\Sr.Proj-STopicsS2-Proj-Code-Repo\.venv\Lib\site-packages\keras\src\models\functional.py:16
#      14 from keras.src.legacy.saving import saving_utils
#      15 from keras.src.legacy.saving import serialization as legacy_serialization
# ---> 16 from keras.src.models.model import Model
#      17 from keras.src.ops.function import Function
#      18 from keras.src.ops.function import _build_map
#
# File c:\Users\maxkr\Desktop\Sr.Proj-STopicsS2-Proj-Code-Repo\.venv\Lib\site-packages\keras\src\models\model.py:12
#      10 from keras.src.models.variable_mapping import map_saveable_variables
#      11 from keras.src.saving import saving_api
# ---> 12 from keras.src.trainers import trainer as base_trainer
#      13 from keras.src.utils import summary_utils
#      14 from keras.src.utils import traceback_utils
#
# File c:\Users\maxkr\Desktop\Sr.Proj-STopicsS2-Proj-Code-Repo\.venv\Lib\site-packages\keras\src\trainers\trainer.py:14
#      12 from keras.src.trainers.compile_utils import CompileLoss
#      13 from keras.src.trainers.compile_utils import CompileMetrics
# ---> 14 from keras.src.trainers.data_adapters import data_adapter_utils
#      15 from keras.src.utils import python_utils
#      16 from keras.src.utils import traceback_utils
#
# File c:\Users\maxkr\Desktop\Sr.Proj-STopicsS2-Proj-Code-Repo\.venv\Lib\site-packages\keras\src\trainers\data_adapters\__init__.py:4
#       1 import types
#       3 from keras.src.distribution import distribution_lib
# ----> 4 from keras.src.trainers.data_adapters import array_data_adapter
#       5 from keras.src.trainers.data_adapters import data_adapter
#       6 from keras.src.trainers.data_adapters import py_dataset_adapter
#
# File c:\Users\maxkr\Desktop\Sr.Proj-STopicsS2-Proj-Code-Repo\.venv\Lib\site-packages\keras\src\trainers\data_adapters\array_data_adapter.py:7
#       4 import numpy as np
#       6 from keras.src import tree
# ----> 7 from keras.src.trainers.data_adapters import array_slicing
#       8 from keras.src.trainers.data_adapters import data_adapter_utils
#       9 from keras.src.trainers.data_adapters.data_adapter import DataAdapter
#
# File c:\Users\maxkr\Desktop\Sr.Proj-STopicsS2-Proj-Code-Repo\.venv\Lib\site-packages\keras\src\trainers\data_adapters\array_slicing.py:12
#       9 from keras.src.utils.module_utils import tensorflow as tf
#      11 try:
# ---> 12     import pandas
#      13 except ImportError:
#      14     pandas = None
#
# File c:\Users\maxkr\Desktop\Sr.Proj-STopicsS2-Proj-Code-Repo\.venv\Lib\site-packages\pandas\__init__.py:151
#     132 from pandas.core.computation.api import eval
#     134 from pandas.core.reshape.api import (
#     135     concat,
#     136     lreshape,
#    (...)    148     qcut,
#     149 )
# --> 151 from pandas import api, arrays, errors, io, plotting, tseries
#     152 from pandas import testing
#     153 from pandas.util._print_versions import show_versions
#
# File c:\Users\maxkr\Desktop\Sr.Proj-STopicsS2-Proj-Code-Repo\.venv\Lib\site-packages\pandas\api\__init__.py:2
#       1 """ public toolkit API """
# ----> 2 from pandas.api import (
#       3     extensions,
#       4     indexers,
#       5     interchange,
#       6     types,
#       7     typing,
#       8 )
#      10 __all__ = [
#      11     "interchange",
#      12     "extensions",
#    (...)     15     "typing",
#      16 ]
#
# File c:\Users\maxkr\Desktop\Sr.Proj-STopicsS2-Proj-Code-Repo\.venv\Lib\site-packages\pandas\api\typing\__init__.py:31
#      19 from pandas.core.window import (
#      20     Expanding,
#      21     ExpandingGroupby,
#    (...)     26     Window,
#      27 )
#      29 # TODO: Can't import Styler without importing jinja2
#      30 # from pandas.io.formats.style import Styler
# ---> 31 from pandas.io.json._json import JsonReader
#      32 from pandas.io.stata import StataReader
#      34 __all__ = [
#      35     "DataFrameGroupBy",
#      36     "DatetimeIndexResamplerGroupby",
#    (...)     54     "Window",
#      55 ]
#
# File c:\Users\maxkr\Desktop\Sr.Proj-STopicsS2-Proj-Code-Repo\.venv\Lib\site-packages\pandas\io\json\__init__.py:1
# ----> 1 from pandas.io.json._json import (
#       2     read_json,
#       3     to_json,
#       4     ujson_dumps,
#       5     ujson_loads,
#       6 )
#       7 from pandas.io.json._table_schema import build_table_schema
#       9 __all__ = [
#      10     "ujson_dumps",
#      11     "ujson_loads",
#    (...)     14     "build_table_schema",
#      15 ]
#
# File c:\Users\maxkr\Desktop\Sr.Proj-STopicsS2-Proj-Code-Repo\.venv\Lib\site-packages\pandas\io\json\_json.py:71
#      66 from pandas.io.json._normalize import convert_to_line_delimits
#      67 from pandas.io.json._table_schema import (
#      68     build_table_schema,
#      69     parse_table_schema,
#      70 )
# ---> 71 from pandas.io.parsers.readers import validate_integer
#      73 if TYPE_CHECKING:
#      74     from collections.abc import (
#      75         Hashable,
#      76         Mapping,
#      77     )
#
# File c:\Users\maxkr\Desktop\Sr.Proj-STopicsS2-Proj-Code-Repo\.venv\Lib\site-packages\pandas\io\parsers\__init__.py:1
# ----> 1 from pandas.io.parsers.readers import (
#       2     TextFileReader,
#       3     TextParser,
#       4     read_csv,
#       5     read_fwf,
#       6     read_table,
#       7 )
#       9 __all__ = ["TextFileReader", "TextParser", "read_csv", "read_fwf", "read_table"]
#
# File c:\Users\maxkr\Desktop\Sr.Proj-STopicsS2-Proj-Code-Repo\.venv\Lib\site-packages\pandas\io\parsers\readers.py:32
#      29 from pandas._config import using_copy_on_write
#      31 from pandas._libs import lib
# ---> 32 from pandas._libs.parsers import STR_NA_VALUES
#      33 from pandas.errors import (
#      34     AbstractMethodError,
#      35     ParserWarning,
#      36 )
#      37 from pandas.util._decorators import Appender
#
# File parsers.pyx:1418, in init pandas._libs.parsers()
#
# AttributeError: partially initialized module 'pandas' has no attribute '_pandas_parser_CAPI' (most likely due to a circular import)
